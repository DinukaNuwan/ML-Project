# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier

# %%
LABEL = 'label_2'
OTHER_LABELS = ['label_1', 'label_3', 'label_4']
LAYERS = ['7', '8', '9', '10', '11', '12']

# %% [markdown]
# ## Load data

# %%
def load_data(x_train_df, y_train_df, x_valid_df, y_valid_df, x_test_df, y_test_df):

    for layer in LAYERS:
        train_df = pd.read_csv(f"dataset/layer_{layer}_train.csv").drop(OTHER_LABELS, axis=1)
        valid_df = pd.read_csv(f"dataset/layer_{layer}_valid.csv").drop(OTHER_LABELS, axis=1)
        test_df = pd.read_csv(f"dataset/layer_{layer}_test.csv").drop(OTHER_LABELS, axis=1)

        train_df = train_df[~np.isnan(train_df[LABEL])]
        valid_df = valid_df[~np.isnan(valid_df[LABEL])]
        test_df = test_df[~np.isnan(test_df[LABEL])]

        x_train_df[layer] = train_df.drop(LABEL, axis=1)
        y_train_df[layer] = train_df[LABEL]
        x_valid_df[layer] = valid_df.drop(LABEL, axis=1)
        y_valid_df[layer] = valid_df[LABEL]
        x_test_df[layer] = test_df.drop(LABEL, axis=1)
        y_test_df[layer] = test_df[LABEL]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# #### Standardize

# %%
def standardize(scalar, x_train, x_valid, x_test, layer):
    features = [f'feature_{i}' for i in range(1, 769)]
    x_train[layer] = pd.DataFrame(scalar.fit_transform(x_train[layer]), columns=features)
    x_valid[layer] = pd.DataFrame(scalar.transform(x_valid[layer]), columns=features)
    x_test[layer] = pd.DataFrame(scalar.transform(x_test[layer]), columns=features)

# %% [markdown]
# #### PCA

# %%
def apply_PCA(x_train, x_valid, x_test, layer, threshold):
    pca = PCA(n_components=threshold, svd_solver='full')
    x_train_pca = pd.DataFrame(pca.fit_transform(x_train[layer]))
    x_valid_pca = pd.DataFrame(pca.transform(x_valid[layer]))
    x_test_pca = pd.DataFrame(pca.transform(x_test[layer]))

    x_train[layer] = x_train_pca
    x_valid[layer] = x_valid_pca
    x_test[layer] = x_test_pca

    print(f"No of features after PCA for layer {layer} = {len(pca.explained_variance_ratio_)}")

# %%
def l7_preprocess(x_train, x_valid, x_test, layer):
    scalar = RobustScaler()
    standardize(scalar, x_train, x_valid, x_test, layer)    
    threshold = 0.97
    apply_PCA(x_train, x_valid, x_test, layer, threshold)


def l8_preprocess(x_train, x_valid, x_test, layer):
    scalar = RobustScaler()
    standardize(scalar, x_train, x_valid, x_test, layer)
    threshold = 0.96
    apply_PCA(x_train, x_valid, x_test, layer, threshold)


def l9_preprocess(x_train, x_valid, x_test, layer):
    scalar = StandardScaler()
    standardize(scalar, x_train, x_valid, x_test, layer)
    threshold = 0.96
    apply_PCA(x_train, x_valid, x_test, layer, threshold)


def l10_preprocess(x_train, x_valid, x_test, layer):
    scalar = StandardScaler()
    standardize(scalar, x_train, x_valid, x_test, layer)
    threshold = 0.96
    apply_PCA(x_train, x_valid, x_test, layer, threshold)


def l11_preprocess(x_train, x_valid, x_test, layer):
    scalar = RobustScaler()
    standardize(scalar, x_train, x_valid, x_test, layer)
    threshold = 0.98
    apply_PCA(x_train, x_valid, x_test, layer, threshold)


def l12_preprocess(x_train, x_valid, x_test, layer):
    scalar = RobustScaler()
    standardize(scalar, x_train, x_valid, x_test, layer)
    threshold = 0.99
    apply_PCA(x_train, x_valid, x_test, layer, threshold)

# %%
def preprocess(x_train, x_valid, x_test, layer):
    if layer == '7':
        l7_preprocess(x_train, x_valid, x_test, layer)
    elif layer == '8':
        l8_preprocess(x_train, x_valid, x_test, layer)
    elif layer == '9':
        l9_preprocess(x_train, x_valid, x_test, layer)
    elif layer == '10':
        l10_preprocess(x_train, x_valid, x_test, layer)
    elif layer == '11':
        l11_preprocess(x_train, x_valid, x_test, layer)
    elif layer == '12':
        l12_preprocess(x_train, x_valid, x_test, layer)

# %% [markdown]
# ## Classifires

# %%
def svm_classifier(x_train, y_train, x_valid, y_valid, params):

  kernel = params['kernel']
  gamma = params['gamma']
  degree = params['degree']
  class_weight = params['class_weight']
  c = params['C']
  
  if (degree):
    model = SVC(kernel=kernel, gamma=gamma, degree=degree, class_weight=class_weight, C=c)
  else: 
    model = SVC(kernel=kernel, gamma=gamma, class_weight=class_weight, C=c)
  model.fit(x_train, y_train)
  y_predict = model.predict(x_valid)
  accuracy = accuracy_score(y_valid, y_predict)

  return {"accuracy": accuracy, "predictions": y_predict, "model": model}

# %% [markdown]
# ## Random grid search

# %%
def random_grid_search(model, param_dist, cv, n_iter, x_train, y_train):

  random_search = RandomizedSearchCV(
      estimator=model,
      param_distributions=param_dist,
      scoring='accuracy',
      cv=cv,
      verbose=1,
      n_jobs=-1,
      n_iter=n_iter
  )

  random_search.fit(x_train, y_train)

  return random_search

# %% [markdown]
# ## Process

# %%
x_train_df = {}
y_train_df = {}
x_valid_df = {}
y_valid_df = {}
x_test_df = {}
y_test_df = {}

load_data(x_train_df, y_train_df, x_valid_df, y_valid_df, x_test_df, y_test_df)

# %%
for layer in LAYERS:
    preprocess(x_train_df, x_valid_df, x_test_df, layer)
# Out:
# No of features after PCA for layer 7 = 411
# No of features after PCA for layer 8 = 349
# No of features after PCA for layer 9 = 350
# No of features after PCA for layer 10 = 310
# No of features after PCA for layer 11 = 277
# No of features after PCA for layer 12 = 280

# %%
params = {
    '7': {'kernel': 'rbf', 'gamma': 'scale', 'degree': 2, 'class_weight': 'balanced', 'C': 1},
    '8': {'kernel': 'poly', 'gamma': 10.0, 'degree': False, 'class_weight': 'balanced', 'C': 1.0},
    '9': {'kernel': 'poly', 'gamma': 100.0, 'degree': False, 'class_weight': 'balanced', 'C': 100.0},
    '10': {'kernel': 'poly', 'gamma': 0.1, 'degree': False, 'class_weight': 'balanced', 'C': 1000.0},
    '11': {'kernel': 'poly', 'gamma': 1000.0, 'degree': False, 'class_weight': 'balanced', 'C': 1.0},
    '12': {'kernel': 'poly', 'gamma': 0.1, 'degree': 1, 'class_weight': 'balanced' ,'C': 10}
}

# %%
history = {}

for layer in LAYERS:
    data = svm_classifier(x_train_df[layer], y_train_df[layer], x_valid_df[layer], y_valid_df[layer], params[layer])
    print(f"Accuracy for layer {layer} = {data['accuracy']}")
    history[layer] = data
# Out:
# Accuracy for layer 7 = 0.9116847826086957
# Accuracy for layer 8 = 0.9266304347826086
# Accuracy for layer 9 = 0.9347826086956522
# Accuracy for layer 10 = 0.9524456521739131
# Accuracy for layer 11 = 0.8464673913043478
# Accuracy for layer 12 = 0.6820652173913043

# %% [markdown]
# #### Meta Model

# %%
data = {}

for layer in LAYERS:
    data[layer] = history[layer]["predictions"]

data["label"] = y_valid_df['7']

data_df = pd.DataFrame(data)

# %%
test_data = {}

for layer in LAYERS:
    model = history[layer]["model"]
    test_data[layer] = model.predict(x_test_df[layer])

test_data["label"] = y_test_df['7']

test_data_df = pd.DataFrame(test_data)

# %%
x_train_meta = data_df.drop(['label'], axis=1)
y_train_meta = data_df['label']

# x_valid_meta = test_data_df.drop(['label'], axis=1)
# y_valid_meta = test_data_df['label']

x_train_meta, x_valid_meta, y_train_meta, y_valid_meta = train_test_split(x_train_meta, y_train_meta, test_size=0.2, random_state=42)

# %%
meta_model_svc = SVC(kernel='linear')
meta_model_svc.fit(x_train_meta, y_train_meta)
y_predict_meta_svc = meta_model_svc.predict(x_valid_meta)
accuracy_svc = accuracy_score(y_valid_meta, y_predict_meta_svc)

print(f"Accuracy of meta model (SVC): {accuracy_svc}")
# Out:
# Accuracy of meta model (SVC): 0.8986486486486487

# %%
meta_model_random = RandomForestClassifier(n_estimators=100, random_state=42)
meta_model_random.fit(x_train_meta, y_train_meta)
y_predict_meta_random = meta_model_random.predict(x_valid_meta)
accuracy_random = accuracy_score(y_valid_meta, y_predict_meta_random)

print(f"Accuracy of meta model (RandomForest): {accuracy_random}")
# Out:
# Accuracy of meta model (RandomForest): 0.9527027027027027

# %%
meta_model_catboost = CatBoostClassifier(iterations=1000, random_seed=42)
meta_model_catboost.fit(x_train_meta, y_train_meta)
y_predict_meta_catboost = meta_model_catboost.predict(x_valid_meta)
accuracy_catboost = accuracy_score(y_valid_meta, y_predict_meta_catboost)

print(f"Accuracy of meta model (CatBoost): {accuracy_catboost}")
# Out:
# Learning rate set to 0.077013
# 0:	learn: 2.4928865	total: 7.91ms	remaining: 7.9s
# 1:	learn: 2.2352803	total: 13.9ms	remaining: 6.94s
# 2:	learn: 2.0318803	total: 38.8ms	remaining: 12.9s
# 3:	learn: 1.8648556	total: 45.3ms	remaining: 11.3s
# 4:	learn: 1.7162606	total: 57.9ms	remaining: 11.5s
# 5:	learn: 1.6155036	total: 65.2ms	remaining: 10.8s
# 6:	learn: 1.5189347	total: 91.6ms	remaining: 13s
# 7:	learn: 1.4408550	total: 94.2ms	remaining: 11.7s
# 8:	learn: 1.3832065	total: 97.5ms	remaining: 10.7s
# 9:	learn: 1.3144856	total: 101ms	remaining: 9.98s
# 10:	learn: 1.2350259	total: 104ms	remaining: 9.31s
# 11:	learn: 1.1725866	total: 107ms	remaining: 8.79s
# 12:	learn: 1.1253872	total: 109ms	remaining: 8.29s
# 13:	learn: 1.0816481	total: 112ms	remaining: 7.87s
# 14:	learn: 1.0299762	total: 115ms	remaining: 7.58s
# 15:	learn: 0.9818565	total: 118ms	remaining: 7.26s
# 16:	learn: 0.9369927	total: 121ms	remaining: 6.97s
# 17:	learn: 0.8996970	total: 123ms	remaining: 6.71s
# 18:	learn: 0.8594310	total: 126ms	remaining: 6.49s
# 19:	learn: 0.8312731	total: 128ms	remaining: 6.29s
# 20:	learn: 0.8022637	total: 131ms	remaining: 6.13s
# 21:	learn: 0.7715033	total: 134ms	remaining: 5.97s
# 22:	learn: 0.7473248	total: 137ms	remaining: 5.81s
# 23:	learn: 0.7210109	total: 140ms	remaining: 5.68s
# 24:	learn: 0.7006758	total: 142ms	remaining: 5.54s
# 25:	learn: 0.6823943	total: 145ms	remaining: 5.42s
# 26:	learn: 0.6609207	total: 147ms	remaining: 5.31s
# 27:	learn: 0.6419580	total: 150ms	remaining: 5.22s
# 28:	learn: 0.6217385	total: 158ms	remaining: 5.29s
# 29:	learn: 0.6048293	total: 167ms	remaining: 5.4s
# 30:	learn: 0.5867860	total: 171ms	remaining: 5.35s
# 31:	learn: 0.5729800	total: 175ms	remaining: 5.28s
# 32:	learn: 0.5580675	total: 179ms	remaining: 5.24s
# 33:	learn: 0.5474710	total: 182ms	remaining: 5.17s
# 34:	learn: 0.5322477	total: 184ms	remaining: 5.08s
# 35:	learn: 0.5183754	total: 187ms	remaining: 5s
# 36:	learn: 0.5066348	total: 189ms	remaining: 4.92s
# 37:	learn: 0.4931934	total: 192ms	remaining: 4.87s
# 38:	learn: 0.4823927	total: 199ms	remaining: 4.9s
# 39:	learn: 0.4723764	total: 203ms	remaining: 4.88s
# 40:	learn: 0.4628029	total: 207ms	remaining: 4.84s
# 41:	learn: 0.4533253	total: 211ms	remaining: 4.81s
# 42:	learn: 0.4428058	total: 214ms	remaining: 4.76s
# 43:	learn: 0.4331588	total: 216ms	remaining: 4.7s
# 44:	learn: 0.4273926	total: 219ms	remaining: 4.64s
# 45:	learn: 0.4222604	total: 221ms	remaining: 4.59s
# 46:	learn: 0.4151616	total: 225ms	remaining: 4.55s
# 47:	learn: 0.4083167	total: 228ms	remaining: 4.52s
# 48:	learn: 0.4005009	total: 231ms	remaining: 4.48s
# 49:	learn: 0.3918919	total: 233ms	remaining: 4.43s
# 50:	learn: 0.3850923	total: 236ms	remaining: 4.39s
# 51:	learn: 0.3756823	total: 239ms	remaining: 4.35s
# 52:	learn: 0.3685920	total: 241ms	remaining: 4.3s
# 53:	learn: 0.3638950	total: 244ms	remaining: 4.27s
# 54:	learn: 0.3573441	total: 246ms	remaining: 4.22s
# 55:	learn: 0.3531061	total: 248ms	remaining: 4.19s
# 56:	learn: 0.3475226	total: 251ms	remaining: 4.15s
# 57:	learn: 0.3439428	total: 254ms	remaining: 4.12s
# 58:	learn: 0.3380529	total: 257ms	remaining: 4.09s
# 59:	learn: 0.3339366	total: 259ms	remaining: 4.06s
# 60:	learn: 0.3285153	total: 262ms	remaining: 4.03s
# 61:	learn: 0.3233220	total: 265ms	remaining: 4s
# 62:	learn: 0.3202941	total: 267ms	remaining: 3.98s
# 63:	learn: 0.3145764	total: 272ms	remaining: 3.97s
# 64:	learn: 0.3081893	total: 274ms	remaining: 3.95s
# 65:	learn: 0.3039249	total: 276ms	remaining: 3.91s
# 66:	learn: 0.3016855	total: 279ms	remaining: 3.88s
# 67:	learn: 0.2988078	total: 281ms	remaining: 3.85s
# 68:	learn: 0.2955752	total: 284ms	remaining: 3.83s
# 69:	learn: 0.2926195	total: 290ms	remaining: 3.85s
# 70:	learn: 0.2876239	total: 295ms	remaining: 3.86s
# 71:	learn: 0.2839088	total: 300ms	remaining: 3.86s
# 72:	learn: 0.2812782	total: 304ms	remaining: 3.85s
# 73:	learn: 0.2780087	total: 306ms	remaining: 3.83s
# 74:	learn: 0.2738214	total: 309ms	remaining: 3.81s
# 75:	learn: 0.2699823	total: 311ms	remaining: 3.78s
# 76:	learn: 0.2672362	total: 314ms	remaining: 3.76s
# 77:	learn: 0.2638681	total: 318ms	remaining: 3.75s
# 78:	learn: 0.2611212	total: 322ms	remaining: 3.75s
# 79:	learn: 0.2570503	total: 325ms	remaining: 3.73s
# 80:	learn: 0.2537199	total: 327ms	remaining: 3.71s
# 81:	learn: 0.2507173	total: 330ms	remaining: 3.7s
# 82:	learn: 0.2478409	total: 337ms	remaining: 3.72s
# 83:	learn: 0.2457382	total: 339ms	remaining: 3.69s
# 84:	learn: 0.2422334	total: 342ms	remaining: 3.68s
# 85:	learn: 0.2396791	total: 345ms	remaining: 3.67s
# 86:	learn: 0.2372706	total: 350ms	remaining: 3.67s
# 87:	learn: 0.2362078	total: 353ms	remaining: 3.66s
# 88:	learn: 0.2339625	total: 355ms	remaining: 3.64s
# 89:	learn: 0.2323980	total: 358ms	remaining: 3.62s
# 90:	learn: 0.2292844	total: 360ms	remaining: 3.6s
# 91:	learn: 0.2272559	total: 363ms	remaining: 3.58s
# 92:	learn: 0.2258141	total: 367ms	remaining: 3.58s
# 93:	learn: 0.2236394	total: 370ms	remaining: 3.57s
# 94:	learn: 0.2214185	total: 373ms	remaining: 3.56s
# 95:	learn: 0.2186778	total: 376ms	remaining: 3.54s
# 96:	learn: 0.2164457	total: 380ms	remaining: 3.53s
# 97:	learn: 0.2139624	total: 384ms	remaining: 3.53s
# 98:	learn: 0.2125253	total: 387ms	remaining: 3.52s
# 99:	learn: 0.2109565	total: 389ms	remaining: 3.5s
# 100:	learn: 0.2079770	total: 391ms	remaining: 3.48s
# 101:	learn: 0.2065412	total: 395ms	remaining: 3.48s
# 102:	learn: 0.2048980	total: 398ms	remaining: 3.47s
# 103:	learn: 0.2024919	total: 401ms	remaining: 3.46s
# 104:	learn: 0.2003770	total: 404ms	remaining: 3.44s
# 105:	learn: 0.1985423	total: 406ms	remaining: 3.43s
# 106:	learn: 0.1973971	total: 410ms	remaining: 3.42s
# 107:	learn: 0.1956341	total: 414ms	remaining: 3.42s
# 108:	learn: 0.1943006	total: 418ms	remaining: 3.42s
# 109:	learn: 0.1928435	total: 421ms	remaining: 3.41s
# 110:	learn: 0.1916088	total: 425ms	remaining: 3.41s
# 111:	learn: 0.1898750	total: 430ms	remaining: 3.41s
# 112:	learn: 0.1884452	total: 432ms	remaining: 3.39s
# 113:	learn: 0.1871821	total: 435ms	remaining: 3.38s
# 114:	learn: 0.1854369	total: 439ms	remaining: 3.38s
# 115:	learn: 0.1839394	total: 442ms	remaining: 3.37s
# 116:	learn: 0.1818900	total: 444ms	remaining: 3.35s
# 117:	learn: 0.1799433	total: 447ms	remaining: 3.34s
# 118:	learn: 0.1788458	total: 449ms	remaining: 3.32s
# 119:	learn: 0.1777894	total: 451ms	remaining: 3.31s
# 120:	learn: 0.1759194	total: 453ms	remaining: 3.29s
# 121:	learn: 0.1741618	total: 459ms	remaining: 3.3s
# 122:	learn: 0.1729856	total: 462ms	remaining: 3.3s
# 123:	learn: 0.1711702	total: 464ms	remaining: 3.28s
# 124:	learn: 0.1697018	total: 467ms	remaining: 3.27s
# 125:	learn: 0.1681515	total: 470ms	remaining: 3.26s
# 126:	learn: 0.1672138	total: 473ms	remaining: 3.25s
# 127:	learn: 0.1654654	total: 475ms	remaining: 3.24s
# 128:	learn: 0.1644239	total: 477ms	remaining: 3.22s
# 129:	learn: 0.1633701	total: 479ms	remaining: 3.21s
# 130:	learn: 0.1616436	total: 482ms	remaining: 3.19s
# 131:	learn: 0.1603445	total: 484ms	remaining: 3.18s
# 132:	learn: 0.1590069	total: 488ms	remaining: 3.18s
# 133:	learn: 0.1576721	total: 490ms	remaining: 3.17s
# 134:	learn: 0.1568185	total: 492ms	remaining: 3.15s
# 135:	learn: 0.1555199	total: 494ms	remaining: 3.14s
# 136:	learn: 0.1539583	total: 496ms	remaining: 3.12s
# 137:	learn: 0.1527560	total: 498ms	remaining: 3.11s
# 138:	learn: 0.1519230	total: 502ms	remaining: 3.11s
# 139:	learn: 0.1511704	total: 505ms	remaining: 3.1s
# 140:	learn: 0.1497756	total: 507ms	remaining: 3.09s
# 141:	learn: 0.1489567	total: 510ms	remaining: 3.08s
# 142:	learn: 0.1479993	total: 512ms	remaining: 3.07s
# 143:	learn: 0.1472275	total: 514ms	remaining: 3.06s
# 144:	learn: 0.1454338	total: 518ms	remaining: 3.05s
# 145:	learn: 0.1444478	total: 520ms	remaining: 3.04s
# 146:	learn: 0.1435332	total: 522ms	remaining: 3.03s
# 147:	learn: 0.1422436	total: 525ms	remaining: 3.02s
# 148:	learn: 0.1414725	total: 527ms	remaining: 3.01s
# 149:	learn: 0.1407998	total: 529ms	remaining: 3s
# 150:	learn: 0.1396745	total: 532ms	remaining: 2.99s
# 151:	learn: 0.1387544	total: 535ms	remaining: 2.99s
# 152:	learn: 0.1376940	total: 538ms	remaining: 2.98s
# 153:	learn: 0.1368063	total: 540ms	remaining: 2.97s
# 154:	learn: 0.1361557	total: 543ms	remaining: 2.96s
# 155:	learn: 0.1352922	total: 545ms	remaining: 2.95s
# 156:	learn: 0.1339782	total: 548ms	remaining: 2.94s
# 157:	learn: 0.1331282	total: 551ms	remaining: 2.94s
# 158:	learn: 0.1319343	total: 554ms	remaining: 2.93s
# 159:	learn: 0.1305824	total: 557ms	remaining: 2.92s
# 160:	learn: 0.1297204	total: 560ms	remaining: 2.92s
# 161:	learn: 0.1285481	total: 562ms	remaining: 2.91s
# 162:	learn: 0.1273781	total: 566ms	remaining: 2.91s
# 163:	learn: 0.1267575	total: 570ms	remaining: 2.9s
# 164:	learn: 0.1260731	total: 574ms	remaining: 2.9s
# 165:	learn: 0.1249740	total: 576ms	remaining: 2.89s
# 166:	learn: 0.1240556	total: 579ms	remaining: 2.89s
# 167:	learn: 0.1232869	total: 583ms	remaining: 2.88s
# 168:	learn: 0.1224968	total: 585ms	remaining: 2.88s
# 169:	learn: 0.1216251	total: 588ms	remaining: 2.87s
# 170:	learn: 0.1210786	total: 590ms	remaining: 2.86s
# 171:	learn: 0.1200566	total: 592ms	remaining: 2.85s
# 172:	learn: 0.1192137	total: 595ms	remaining: 2.84s
# 173:	learn: 0.1183528	total: 597ms	remaining: 2.83s
# 174:	learn: 0.1178452	total: 599ms	remaining: 2.82s
# 175:	learn: 0.1171580	total: 601ms	remaining: 2.81s
# 176:	learn: 0.1158727	total: 603ms	remaining: 2.8s
# 177:	learn: 0.1151444	total: 604ms	remaining: 2.79s
# 178:	learn: 0.1142788	total: 606ms	remaining: 2.78s
# 179:	learn: 0.1137958	total: 608ms	remaining: 2.77s
# 180:	learn: 0.1128991	total: 610ms	remaining: 2.76s
# 181:	learn: 0.1122274	total: 612ms	remaining: 2.75s
# 182:	learn: 0.1118450	total: 614ms	remaining: 2.74s
# 183:	learn: 0.1108877	total: 617ms	remaining: 2.73s
# 184:	learn: 0.1103756	total: 619ms	remaining: 2.72s
# 185:	learn: 0.1097774	total: 620ms	remaining: 2.71s
# 186:	learn: 0.1090613	total: 622ms	remaining: 2.7s
# 187:	learn: 0.1085040	total: 624ms	remaining: 2.7s
# 188:	learn: 0.1077977	total: 626ms	remaining: 2.69s
# 189:	learn: 0.1070258	total: 629ms	remaining: 2.68s
# 190:	learn: 0.1061895	total: 631ms	remaining: 2.67s
# 191:	learn: 0.1053341	total: 634ms	remaining: 2.67s
# 192:	learn: 0.1043595	total: 636ms	remaining: 2.66s
# 193:	learn: 0.1037555	total: 638ms	remaining: 2.65s
# 194:	learn: 0.1030705	total: 640ms	remaining: 2.64s
# 195:	learn: 0.1026346	total: 643ms	remaining: 2.64s
# 196:	learn: 0.1019516	total: 645ms	remaining: 2.63s
# 197:	learn: 0.1013949	total: 648ms	remaining: 2.62s
# 198:	learn: 0.1006304	total: 650ms	remaining: 2.62s
# 199:	learn: 0.1001780	total: 652ms	remaining: 2.61s
# 200:	learn: 0.0996481	total: 654ms	remaining: 2.6s
# 201:	learn: 0.0988656	total: 657ms	remaining: 2.59s
# 202:	learn: 0.0984931	total: 660ms	remaining: 2.59s
# 203:	learn: 0.0980939	total: 662ms	remaining: 2.58s
# 204:	learn: 0.0973957	total: 664ms	remaining: 2.58s
# 205:	learn: 0.0966911	total: 666ms	remaining: 2.57s
# 206:	learn: 0.0961885	total: 668ms	remaining: 2.56s
# 207:	learn: 0.0958478	total: 670ms	remaining: 2.55s
# 208:	learn: 0.0950711	total: 672ms	remaining: 2.54s
# 209:	learn: 0.0944592	total: 674ms	remaining: 2.54s
# 210:	learn: 0.0937959	total: 677ms	remaining: 2.53s
# 211:	learn: 0.0933497	total: 680ms	remaining: 2.53s
# 212:	learn: 0.0928190	total: 682ms	remaining: 2.52s
# 213:	learn: 0.0921976	total: 684ms	remaining: 2.51s
# 214:	learn: 0.0914628	total: 686ms	remaining: 2.5s
# 215:	learn: 0.0911317	total: 688ms	remaining: 2.5s
# 216:	learn: 0.0907703	total: 690ms	remaining: 2.49s
# 217:	learn: 0.0901574	total: 692ms	remaining: 2.48s
# 218:	learn: 0.0894950	total: 694ms	remaining: 2.47s
# 219:	learn: 0.0888318	total: 695ms	remaining: 2.46s
# 220:	learn: 0.0883445	total: 697ms	remaining: 2.46s
# 221:	learn: 0.0879534	total: 699ms	remaining: 2.45s
# 222:	learn: 0.0874181	total: 701ms	remaining: 2.44s
# 223:	learn: 0.0869267	total: 703ms	remaining: 2.43s
# 224:	learn: 0.0864066	total: 705ms	remaining: 2.43s
# 225:	learn: 0.0859445	total: 707ms	remaining: 2.42s
# 226:	learn: 0.0856001	total: 709ms	remaining: 2.41s
# 227:	learn: 0.0852509	total: 711ms	remaining: 2.41s
# 228:	learn: 0.0847106	total: 713ms	remaining: 2.4s
# 229:	learn: 0.0843246	total: 714ms	remaining: 2.39s
# 230:	learn: 0.0838319	total: 716ms	remaining: 2.38s
# 231:	learn: 0.0835048	total: 718ms	remaining: 2.38s
# 232:	learn: 0.0831945	total: 720ms	remaining: 2.37s
# 233:	learn: 0.0825872	total: 722ms	remaining: 2.36s
# 234:	learn: 0.0820517	total: 725ms	remaining: 2.36s
# 235:	learn: 0.0815827	total: 727ms	remaining: 2.35s
# 236:	learn: 0.0811760	total: 729ms	remaining: 2.35s
# 237:	learn: 0.0808115	total: 731ms	remaining: 2.34s
# 238:	learn: 0.0803457	total: 735ms	remaining: 2.34s
# 239:	learn: 0.0800018	total: 737ms	remaining: 2.33s
# 240:	learn: 0.0794052	total: 739ms	remaining: 2.33s
# 241:	learn: 0.0788681	total: 741ms	remaining: 2.32s
# 242:	learn: 0.0784213	total: 743ms	remaining: 2.31s
# 243:	learn: 0.0778247	total: 745ms	remaining: 2.31s
# 244:	learn: 0.0770503	total: 748ms	remaining: 2.3s
# 245:	learn: 0.0766057	total: 750ms	remaining: 2.3s
# 246:	learn: 0.0761349	total: 752ms	remaining: 2.29s
# 247:	learn: 0.0756882	total: 754ms	remaining: 2.29s
# 248:	learn: 0.0752084	total: 756ms	remaining: 2.28s
# 249:	learn: 0.0748122	total: 758ms	remaining: 2.27s
# 250:	learn: 0.0743239	total: 760ms	remaining: 2.27s
# 251:	learn: 0.0739156	total: 762ms	remaining: 2.26s
# 252:	learn: 0.0735279	total: 765ms	remaining: 2.26s
# 253:	learn: 0.0730954	total: 766ms	remaining: 2.25s
# 254:	learn: 0.0726749	total: 768ms	remaining: 2.24s
# 255:	learn: 0.0721531	total: 770ms	remaining: 2.24s
# 256:	learn: 0.0717050	total: 772ms	remaining: 2.23s
# 257:	learn: 0.0713415	total: 773ms	remaining: 2.22s
# 258:	learn: 0.0710206	total: 775ms	remaining: 2.22s
# 259:	learn: 0.0707724	total: 777ms	remaining: 2.21s
# 260:	learn: 0.0703744	total: 779ms	remaining: 2.21s
# 261:	learn: 0.0700455	total: 781ms	remaining: 2.2s
# 262:	learn: 0.0695363	total: 783ms	remaining: 2.19s
# 263:	learn: 0.0692754	total: 785ms	remaining: 2.19s
# 264:	learn: 0.0688826	total: 787ms	remaining: 2.18s
# 265:	learn: 0.0685199	total: 788ms	remaining: 2.17s
# 266:	learn: 0.0682041	total: 790ms	remaining: 2.17s
# 267:	learn: 0.0677741	total: 792ms	remaining: 2.16s
# 268:	learn: 0.0675509	total: 794ms	remaining: 2.16s
# 269:	learn: 0.0672494	total: 796ms	remaining: 2.15s
# 270:	learn: 0.0668638	total: 798ms	remaining: 2.15s
# 271:	learn: 0.0666306	total: 800ms	remaining: 2.14s
# 272:	learn: 0.0663080	total: 802ms	remaining: 2.14s
# 273:	learn: 0.0659990	total: 804ms	remaining: 2.13s
# 274:	learn: 0.0656590	total: 806ms	remaining: 2.13s
# 275:	learn: 0.0653423	total: 808ms	remaining: 2.12s
# 276:	learn: 0.0651149	total: 810ms	remaining: 2.11s
# 277:	learn: 0.0648357	total: 812ms	remaining: 2.11s
# 278:	learn: 0.0645222	total: 814ms	remaining: 2.1s
# 279:	learn: 0.0643470	total: 816ms	remaining: 2.1s
# 280:	learn: 0.0641095	total: 817ms	remaining: 2.09s
# 281:	learn: 0.0638556	total: 821ms	remaining: 2.09s
# 282:	learn: 0.0635664	total: 824ms	remaining: 2.09s
# 283:	learn: 0.0633610	total: 826ms	remaining: 2.08s
# 284:	learn: 0.0630967	total: 829ms	remaining: 2.08s
# 285:	learn: 0.0628215	total: 832ms	remaining: 2.08s
# 286:	learn: 0.0625702	total: 834ms	remaining: 2.07s
# 287:	learn: 0.0623615	total: 836ms	remaining: 2.07s
# 288:	learn: 0.0621683	total: 838ms	remaining: 2.06s
# 289:	learn: 0.0619164	total: 840ms	remaining: 2.06s
# 290:	learn: 0.0617152	total: 842ms	remaining: 2.05s
# 291:	learn: 0.0615270	total: 844ms	remaining: 2.05s
# 292:	learn: 0.0612025	total: 846ms	remaining: 2.04s
# 293:	learn: 0.0608794	total: 848ms	remaining: 2.04s
# 294:	learn: 0.0606980	total: 850ms	remaining: 2.03s
# 295:	learn: 0.0604809	total: 852ms	remaining: 2.02s
# 296:	learn: 0.0602092	total: 854ms	remaining: 2.02s
# 297:	learn: 0.0600365	total: 857ms	remaining: 2.02s
# 298:	learn: 0.0596043	total: 861ms	remaining: 2.02s
# 299:	learn: 0.0592113	total: 865ms	remaining: 2.02s
# 300:	learn: 0.0588921	total: 868ms	remaining: 2.02s
# 301:	learn: 0.0586495	total: 872ms	remaining: 2.01s
# 302:	learn: 0.0583659	total: 875ms	remaining: 2.01s
# 303:	learn: 0.0581099	total: 877ms	remaining: 2.01s
# 304:	learn: 0.0579264	total: 879ms	remaining: 2s
# 305:	learn: 0.0576541	total: 881ms	remaining: 2s
# 306:	learn: 0.0573638	total: 883ms	remaining: 1.99s
# 307:	learn: 0.0570947	total: 886ms	remaining: 1.99s
# 308:	learn: 0.0568149	total: 890ms	remaining: 1.99s
# 309:	learn: 0.0566457	total: 895ms	remaining: 1.99s
# 310:	learn: 0.0564514	total: 898ms	remaining: 1.99s
# 311:	learn: 0.0562119	total: 900ms	remaining: 1.98s
# 312:	learn: 0.0560665	total: 902ms	remaining: 1.98s
# 313:	learn: 0.0558292	total: 905ms	remaining: 1.98s
# 314:	learn: 0.0556985	total: 909ms	remaining: 1.98s
# 315:	learn: 0.0554041	total: 911ms	remaining: 1.97s
# 316:	learn: 0.0552053	total: 913ms	remaining: 1.97s
# 317:	learn: 0.0549045	total: 915ms	remaining: 1.96s
# 318:	learn: 0.0546585	total: 917ms	remaining: 1.96s
# 319:	learn: 0.0543891	total: 919ms	remaining: 1.95s
# 320:	learn: 0.0540357	total: 922ms	remaining: 1.95s
# 321:	learn: 0.0537729	total: 924ms	remaining: 1.95s
# 322:	learn: 0.0535193	total: 926ms	remaining: 1.94s
# 323:	learn: 0.0532696	total: 929ms	remaining: 1.94s
# 324:	learn: 0.0530497	total: 931ms	remaining: 1.93s
# 325:	learn: 0.0528786	total: 934ms	remaining: 1.93s
# 326:	learn: 0.0526839	total: 936ms	remaining: 1.93s
# 327:	learn: 0.0524967	total: 938ms	remaining: 1.92s
# 328:	learn: 0.0522661	total: 940ms	remaining: 1.92s
# 329:	learn: 0.0521341	total: 942ms	remaining: 1.91s
# 330:	learn: 0.0519740	total: 944ms	remaining: 1.91s
# 331:	learn: 0.0518433	total: 946ms	remaining: 1.9s
# 332:	learn: 0.0516601	total: 949ms	remaining: 1.9s
# 333:	learn: 0.0514827	total: 955ms	remaining: 1.9s
# 334:	learn: 0.0513605	total: 959ms	remaining: 1.9s
# 335:	learn: 0.0511437	total: 963ms	remaining: 1.9s
# 336:	learn: 0.0510497	total: 966ms	remaining: 1.9s
# 337:	learn: 0.0509300	total: 969ms	remaining: 1.9s
# 338:	learn: 0.0506867	total: 972ms	remaining: 1.9s
# 339:	learn: 0.0504909	total: 975ms	remaining: 1.89s
# 340:	learn: 0.0501768	total: 977ms	remaining: 1.89s
# 341:	learn: 0.0499158	total: 980ms	remaining: 1.89s
# 342:	learn: 0.0497219	total: 985ms	remaining: 1.89s
# 343:	learn: 0.0494890	total: 989ms	remaining: 1.89s
# 344:	learn: 0.0493621	total: 993ms	remaining: 1.88s
# 345:	learn: 0.0491620	total: 995ms	remaining: 1.88s
# 346:	learn: 0.0490067	total: 999ms	remaining: 1.88s
# 347:	learn: 0.0488901	total: 1s	remaining: 1.88s
# 348:	learn: 0.0487405	total: 1.01s	remaining: 1.88s
# 349:	learn: 0.0485190	total: 1.01s	remaining: 1.87s
# 350:	learn: 0.0483616	total: 1.01s	remaining: 1.87s
# 351:	learn: 0.0482255	total: 1.01s	remaining: 1.87s
# 352:	learn: 0.0480183	total: 1.02s	remaining: 1.86s
# 353:	learn: 0.0478052	total: 1.02s	remaining: 1.86s
# 354:	learn: 0.0476544	total: 1.02s	remaining: 1.85s
# 355:	learn: 0.0474494	total: 1.02s	remaining: 1.85s
# 356:	learn: 0.0473446	total: 1.02s	remaining: 1.85s
# 357:	learn: 0.0472159	total: 1.03s	remaining: 1.84s
# 358:	learn: 0.0470661	total: 1.03s	remaining: 1.84s
# 359:	learn: 0.0469834	total: 1.03s	remaining: 1.84s
# 360:	learn: 0.0467642	total: 1.04s	remaining: 1.84s
# 361:	learn: 0.0464859	total: 1.04s	remaining: 1.84s
# 362:	learn: 0.0463350	total: 1.04s	remaining: 1.83s
# 363:	learn: 0.0461684	total: 1.05s	remaining: 1.83s
# 364:	learn: 0.0459719	total: 1.05s	remaining: 1.83s
# 365:	learn: 0.0456967	total: 1.05s	remaining: 1.83s
# 366:	learn: 0.0455145	total: 1.06s	remaining: 1.82s
# 367:	learn: 0.0453375	total: 1.06s	remaining: 1.82s
# 368:	learn: 0.0451830	total: 1.06s	remaining: 1.81s
# 369:	learn: 0.0450330	total: 1.06s	remaining: 1.81s
# 370:	learn: 0.0448348	total: 1.07s	remaining: 1.81s
# 371:	learn: 0.0446800	total: 1.07s	remaining: 1.8s
# 372:	learn: 0.0444976	total: 1.07s	remaining: 1.8s
# 373:	learn: 0.0443320	total: 1.07s	remaining: 1.8s
# 374:	learn: 0.0442359	total: 1.08s	remaining: 1.79s
# 375:	learn: 0.0440902	total: 1.08s	remaining: 1.79s
# 376:	learn: 0.0439479	total: 1.08s	remaining: 1.78s
# 377:	learn: 0.0437715	total: 1.08s	remaining: 1.78s
# 378:	learn: 0.0436276	total: 1.08s	remaining: 1.78s
# 379:	learn: 0.0435071	total: 1.09s	remaining: 1.77s
# 380:	learn: 0.0433612	total: 1.09s	remaining: 1.77s
# 381:	learn: 0.0432437	total: 1.09s	remaining: 1.77s
# 382:	learn: 0.0431043	total: 1.09s	remaining: 1.76s
# 383:	learn: 0.0429731	total: 1.1s	remaining: 1.76s
# 384:	learn: 0.0428723	total: 1.1s	remaining: 1.75s
# 385:	learn: 0.0427842	total: 1.1s	remaining: 1.75s
# 386:	learn: 0.0426542	total: 1.1s	remaining: 1.75s
# 387:	learn: 0.0424454	total: 1.1s	remaining: 1.74s
# 388:	learn: 0.0422823	total: 1.11s	remaining: 1.74s
# 389:	learn: 0.0421717	total: 1.11s	remaining: 1.74s
# 390:	learn: 0.0420726	total: 1.11s	remaining: 1.73s
# 391:	learn: 0.0419511	total: 1.11s	remaining: 1.73s
# 392:	learn: 0.0417603	total: 1.12s	remaining: 1.73s
# 393:	learn: 0.0416085	total: 1.12s	remaining: 1.72s
# 394:	learn: 0.0414624	total: 1.12s	remaining: 1.72s
# 395:	learn: 0.0413085	total: 1.13s	remaining: 1.72s
# 396:	learn: 0.0411857	total: 1.13s	remaining: 1.71s
# 397:	learn: 0.0410394	total: 1.13s	remaining: 1.71s
# 398:	learn: 0.0408952	total: 1.13s	remaining: 1.71s
# 399:	learn: 0.0407975	total: 1.14s	remaining: 1.7s
# 400:	learn: 0.0406133	total: 1.14s	remaining: 1.7s
# 401:	learn: 0.0404624	total: 1.14s	remaining: 1.7s
# 402:	learn: 0.0402982	total: 1.14s	remaining: 1.69s
# 403:	learn: 0.0401929	total: 1.15s	remaining: 1.69s
# 404:	learn: 0.0400462	total: 1.15s	remaining: 1.69s
# 405:	learn: 0.0399217	total: 1.15s	remaining: 1.68s
# 406:	learn: 0.0398503	total: 1.15s	remaining: 1.68s
# 407:	learn: 0.0397726	total: 1.16s	remaining: 1.68s
# 408:	learn: 0.0396409	total: 1.16s	remaining: 1.67s
# 409:	learn: 0.0395204	total: 1.16s	remaining: 1.67s
# 410:	learn: 0.0393920	total: 1.16s	remaining: 1.67s
# 411:	learn: 0.0392785	total: 1.17s	remaining: 1.66s
# 412:	learn: 0.0391585	total: 1.17s	remaining: 1.66s
# 413:	learn: 0.0390269	total: 1.17s	remaining: 1.66s
# 414:	learn: 0.0388782	total: 1.17s	remaining: 1.65s
# 415:	learn: 0.0387701	total: 1.18s	remaining: 1.65s
# 416:	learn: 0.0386713	total: 1.18s	remaining: 1.65s
# 417:	learn: 0.0385852	total: 1.18s	remaining: 1.65s
# 418:	learn: 0.0384974	total: 1.18s	remaining: 1.64s
# 419:	learn: 0.0383260	total: 1.19s	remaining: 1.64s
# 420:	learn: 0.0382456	total: 1.19s	remaining: 1.64s
# 421:	learn: 0.0380229	total: 1.19s	remaining: 1.63s
# 422:	learn: 0.0379348	total: 1.19s	remaining: 1.63s
# 423:	learn: 0.0377772	total: 1.2s	remaining: 1.63s
# 424:	learn: 0.0377121	total: 1.2s	remaining: 1.62s
# 425:	learn: 0.0376299	total: 1.2s	remaining: 1.62s
# 426:	learn: 0.0375386	total: 1.2s	remaining: 1.62s
# 427:	learn: 0.0374018	total: 1.21s	remaining: 1.61s
# 428:	learn: 0.0373173	total: 1.21s	remaining: 1.61s
# 429:	learn: 0.0372036	total: 1.21s	remaining: 1.6s
# 430:	learn: 0.0371265	total: 1.21s	remaining: 1.6s
# 431:	learn: 0.0370187	total: 1.22s	remaining: 1.6s
# 432:	learn: 0.0369458	total: 1.22s	remaining: 1.6s
# 433:	learn: 0.0367755	total: 1.22s	remaining: 1.59s
# 434:	learn: 0.0366390	total: 1.22s	remaining: 1.59s
# 435:	learn: 0.0365455	total: 1.23s	remaining: 1.58s
# 436:	learn: 0.0364682	total: 1.23s	remaining: 1.58s
# 437:	learn: 0.0363286	total: 1.23s	remaining: 1.58s
# 438:	learn: 0.0362572	total: 1.23s	remaining: 1.57s
# 439:	learn: 0.0361265	total: 1.23s	remaining: 1.57s
# 440:	learn: 0.0359934	total: 1.24s	remaining: 1.57s
# 441:	learn: 0.0359015	total: 1.24s	remaining: 1.56s
# 442:	learn: 0.0357173	total: 1.24s	remaining: 1.56s
# 443:	learn: 0.0356603	total: 1.24s	remaining: 1.55s
# 444:	learn: 0.0356038	total: 1.24s	remaining: 1.55s
# 445:	learn: 0.0355375	total: 1.25s	remaining: 1.55s
# 446:	learn: 0.0354645	total: 1.25s	remaining: 1.54s
# 447:	learn: 0.0353582	total: 1.25s	remaining: 1.54s
# 448:	learn: 0.0352520	total: 1.25s	remaining: 1.53s
# 449:	learn: 0.0351592	total: 1.25s	remaining: 1.53s
# 450:	learn: 0.0350426	total: 1.25s	remaining: 1.53s
# 451:	learn: 0.0349747	total: 1.26s	remaining: 1.52s
# 452:	learn: 0.0349029	total: 1.26s	remaining: 1.52s
# 453:	learn: 0.0348069	total: 1.26s	remaining: 1.52s
# 454:	learn: 0.0347295	total: 1.26s	remaining: 1.51s
# 455:	learn: 0.0346550	total: 1.26s	remaining: 1.51s
# 456:	learn: 0.0345815	total: 1.27s	remaining: 1.5s
# 457:	learn: 0.0345175	total: 1.27s	remaining: 1.5s
# 458:	learn: 0.0344423	total: 1.27s	remaining: 1.5s
# 459:	learn: 0.0342871	total: 1.27s	remaining: 1.5s
# 460:	learn: 0.0342222	total: 1.28s	remaining: 1.49s
# 461:	learn: 0.0341009	total: 1.28s	remaining: 1.49s
# 462:	learn: 0.0339583	total: 1.28s	remaining: 1.49s
# 463:	learn: 0.0339000	total: 1.28s	remaining: 1.48s
# 464:	learn: 0.0338374	total: 1.28s	remaining: 1.48s
# 465:	learn: 0.0337721	total: 1.28s	remaining: 1.47s
# 466:	learn: 0.0336659	total: 1.29s	remaining: 1.47s
# 467:	learn: 0.0336096	total: 1.29s	remaining: 1.47s
# 468:	learn: 0.0335011	total: 1.29s	remaining: 1.46s
# 469:	learn: 0.0333897	total: 1.29s	remaining: 1.46s
# 470:	learn: 0.0333024	total: 1.3s	remaining: 1.46s
# 471:	learn: 0.0332006	total: 1.3s	remaining: 1.45s
# 472:	learn: 0.0331433	total: 1.3s	remaining: 1.45s
# 473:	learn: 0.0330744	total: 1.3s	remaining: 1.45s
# 474:	learn: 0.0329672	total: 1.3s	remaining: 1.44s
# 475:	learn: 0.0328868	total: 1.31s	remaining: 1.44s
# 476:	learn: 0.0327921	total: 1.31s	remaining: 1.44s
# 477:	learn: 0.0326988	total: 1.31s	remaining: 1.43s
# 478:	learn: 0.0326425	total: 1.31s	remaining: 1.43s
# 479:	learn: 0.0325263	total: 1.32s	remaining: 1.43s
# 480:	learn: 0.0324390	total: 1.32s	remaining: 1.42s
# 481:	learn: 0.0323415	total: 1.32s	remaining: 1.42s
# 482:	learn: 0.0322633	total: 1.32s	remaining: 1.42s
# 483:	learn: 0.0321702	total: 1.32s	remaining: 1.41s
# 484:	learn: 0.0321043	total: 1.33s	remaining: 1.41s
# 485:	learn: 0.0320304	total: 1.33s	remaining: 1.41s
# 486:	learn: 0.0319900	total: 1.33s	remaining: 1.4s
# 487:	learn: 0.0318859	total: 1.33s	remaining: 1.4s
# 488:	learn: 0.0317919	total: 1.33s	remaining: 1.39s
# 489:	learn: 0.0316854	total: 1.34s	remaining: 1.39s
# 490:	learn: 0.0315814	total: 1.34s	remaining: 1.39s
# 491:	learn: 0.0315045	total: 1.34s	remaining: 1.39s
# 492:	learn: 0.0314625	total: 1.35s	remaining: 1.38s
# 493:	learn: 0.0313654	total: 1.35s	remaining: 1.38s
# 494:	learn: 0.0312697	total: 1.35s	remaining: 1.38s
# 495:	learn: 0.0312149	total: 1.35s	remaining: 1.38s
# 496:	learn: 0.0310846	total: 1.35s	remaining: 1.37s
# 497:	learn: 0.0310082	total: 1.36s	remaining: 1.37s
# 498:	learn: 0.0309184	total: 1.36s	remaining: 1.37s
# 499:	learn: 0.0308233	total: 1.36s	remaining: 1.36s
# 500:	learn: 0.0307400	total: 1.37s	remaining: 1.36s
# 501:	learn: 0.0306817	total: 1.37s	remaining: 1.36s
# 502:	learn: 0.0305862	total: 1.37s	remaining: 1.35s
# 503:	learn: 0.0305294	total: 1.37s	remaining: 1.35s
# 504:	learn: 0.0304507	total: 1.38s	remaining: 1.35s
# 505:	learn: 0.0303655	total: 1.38s	remaining: 1.34s
# 506:	learn: 0.0302753	total: 1.38s	remaining: 1.34s
# 507:	learn: 0.0302322	total: 1.38s	remaining: 1.34s
# 508:	learn: 0.0301655	total: 1.38s	remaining: 1.33s
# 509:	learn: 0.0301157	total: 1.38s	remaining: 1.33s
# 510:	learn: 0.0300676	total: 1.39s	remaining: 1.33s
# 511:	learn: 0.0300000	total: 1.39s	remaining: 1.32s
# 512:	learn: 0.0298908	total: 1.39s	remaining: 1.32s
# 513:	learn: 0.0298375	total: 1.39s	remaining: 1.31s
# 514:	learn: 0.0297446	total: 1.39s	remaining: 1.31s
# 515:	learn: 0.0296756	total: 1.39s	remaining: 1.31s
# 516:	learn: 0.0295940	total: 1.4s	remaining: 1.3s
# 517:	learn: 0.0295008	total: 1.4s	remaining: 1.3s
# 518:	learn: 0.0294105	total: 1.4s	remaining: 1.3s
# 519:	learn: 0.0293133	total: 1.4s	remaining: 1.29s
# 520:	learn: 0.0292294	total: 1.4s	remaining: 1.29s
# 521:	learn: 0.0291415	total: 1.41s	remaining: 1.29s
# 522:	learn: 0.0290625	total: 1.41s	remaining: 1.28s
# 523:	learn: 0.0289966	total: 1.41s	remaining: 1.28s
# 524:	learn: 0.0289156	total: 1.41s	remaining: 1.28s
# 525:	learn: 0.0288326	total: 1.41s	remaining: 1.27s
# 526:	learn: 0.0287684	total: 1.42s	remaining: 1.27s
# 527:	learn: 0.0286975	total: 1.42s	remaining: 1.27s
# 528:	learn: 0.0286582	total: 1.42s	remaining: 1.26s
# 529:	learn: 0.0286066	total: 1.42s	remaining: 1.26s
# 530:	learn: 0.0285356	total: 1.42s	remaining: 1.26s
# 531:	learn: 0.0284559	total: 1.42s	remaining: 1.25s
# 532:	learn: 0.0283990	total: 1.43s	remaining: 1.25s
# 533:	learn: 0.0283092	total: 1.43s	remaining: 1.25s
# 534:	learn: 0.0282643	total: 1.43s	remaining: 1.24s
# 535:	learn: 0.0281751	total: 1.43s	remaining: 1.24s
# 536:	learn: 0.0281055	total: 1.44s	remaining: 1.24s
# 537:	learn: 0.0280285	total: 1.44s	remaining: 1.23s
# 538:	learn: 0.0279512	total: 1.44s	remaining: 1.23s
# 539:	learn: 0.0278844	total: 1.44s	remaining: 1.23s
# 540:	learn: 0.0278156	total: 1.44s	remaining: 1.22s
# 541:	learn: 0.0277609	total: 1.44s	remaining: 1.22s
# 542:	learn: 0.0276745	total: 1.45s	remaining: 1.22s
# 543:	learn: 0.0276276	total: 1.45s	remaining: 1.21s
# 544:	learn: 0.0275711	total: 1.45s	remaining: 1.21s
# 545:	learn: 0.0275033	total: 1.45s	remaining: 1.21s
# 546:	learn: 0.0274517	total: 1.45s	remaining: 1.2s
# 547:	learn: 0.0273813	total: 1.46s	remaining: 1.2s
# 548:	learn: 0.0273119	total: 1.46s	remaining: 1.2s
# 549:	learn: 0.0272449	total: 1.46s	remaining: 1.19s
# 550:	learn: 0.0271510	total: 1.46s	remaining: 1.19s
# 551:	learn: 0.0271043	total: 1.46s	remaining: 1.19s
# 552:	learn: 0.0270223	total: 1.47s	remaining: 1.18s
# 553:	learn: 0.0269832	total: 1.47s	remaining: 1.18s
# 554:	learn: 0.0269189	total: 1.47s	remaining: 1.18s
# 555:	learn: 0.0268564	total: 1.47s	remaining: 1.17s
# 556:	learn: 0.0267791	total: 1.47s	remaining: 1.17s
# 557:	learn: 0.0267094	total: 1.47s	remaining: 1.17s
# 558:	learn: 0.0266303	total: 1.48s	remaining: 1.16s
# 559:	learn: 0.0265778	total: 1.48s	remaining: 1.16s
# 560:	learn: 0.0265387	total: 1.48s	remaining: 1.16s
# 561:	learn: 0.0264696	total: 1.48s	remaining: 1.15s
# 562:	learn: 0.0264144	total: 1.48s	remaining: 1.15s
# 563:	learn: 0.0263460	total: 1.49s	remaining: 1.15s
# 564:	learn: 0.0263029	total: 1.49s	remaining: 1.15s
# 565:	learn: 0.0262350	total: 1.49s	remaining: 1.14s
# 566:	learn: 0.0261672	total: 1.49s	remaining: 1.14s
# 567:	learn: 0.0261005	total: 1.49s	remaining: 1.14s
# 568:	learn: 0.0260657	total: 1.5s	remaining: 1.13s
# 569:	learn: 0.0260079	total: 1.5s	remaining: 1.13s
# 570:	learn: 0.0259436	total: 1.5s	remaining: 1.13s
# 571:	learn: 0.0258936	total: 1.5s	remaining: 1.12s
# 572:	learn: 0.0258486	total: 1.5s	remaining: 1.12s
# 573:	learn: 0.0257886	total: 1.5s	remaining: 1.12s
# 574:	learn: 0.0257218	total: 1.51s	remaining: 1.11s
# 575:	learn: 0.0256518	total: 1.51s	remaining: 1.11s
# 576:	learn: 0.0255960	total: 1.51s	remaining: 1.11s
# 577:	learn: 0.0255475	total: 1.51s	remaining: 1.1s
# 578:	learn: 0.0254634	total: 1.52s	remaining: 1.1s
# 579:	learn: 0.0253990	total: 1.52s	remaining: 1.1s
# 580:	learn: 0.0253252	total: 1.52s	remaining: 1.1s
# 581:	learn: 0.0252863	total: 1.52s	remaining: 1.09s
# 582:	learn: 0.0252441	total: 1.53s	remaining: 1.09s
# 583:	learn: 0.0251970	total: 1.53s	remaining: 1.09s
# 584:	learn: 0.0251401	total: 1.53s	remaining: 1.09s
# 585:	learn: 0.0250688	total: 1.53s	remaining: 1.08s
# 586:	learn: 0.0250250	total: 1.54s	remaining: 1.08s
# 587:	learn: 0.0249775	total: 1.54s	remaining: 1.08s
# 588:	learn: 0.0249378	total: 1.54s	remaining: 1.08s
# 589:	learn: 0.0248683	total: 1.54s	remaining: 1.07s
# 590:	learn: 0.0248128	total: 1.54s	remaining: 1.07s
# 591:	learn: 0.0247411	total: 1.55s	remaining: 1.07s
# 592:	learn: 0.0246790	total: 1.55s	remaining: 1.06s
# 593:	learn: 0.0246470	total: 1.55s	remaining: 1.06s
# 594:	learn: 0.0245976	total: 1.55s	remaining: 1.06s
# 595:	learn: 0.0245301	total: 1.55s	remaining: 1.05s
# 596:	learn: 0.0244531	total: 1.56s	remaining: 1.05s
# 597:	learn: 0.0243887	total: 1.56s	remaining: 1.05s
# 598:	learn: 0.0243145	total: 1.56s	remaining: 1.04s
# 599:	learn: 0.0242650	total: 1.56s	remaining: 1.04s
# 600:	learn: 0.0242373	total: 1.56s	remaining: 1.04s
# 601:	learn: 0.0241724	total: 1.57s	remaining: 1.04s
# 602:	learn: 0.0241148	total: 1.57s	remaining: 1.03s
# 603:	learn: 0.0240653	total: 1.57s	remaining: 1.03s
# 604:	learn: 0.0240044	total: 1.57s	remaining: 1.03s
# 605:	learn: 0.0239429	total: 1.58s	remaining: 1.02s
# 606:	learn: 0.0239011	total: 1.58s	remaining: 1.02s
# 607:	learn: 0.0238587	total: 1.58s	remaining: 1.02s
# 608:	learn: 0.0237964	total: 1.58s	remaining: 1.01s
# 609:	learn: 0.0237404	total: 1.58s	remaining: 1.01s
# 610:	learn: 0.0236903	total: 1.58s	remaining: 1.01s
# 611:	learn: 0.0236459	total: 1.59s	remaining: 1.01s
# 612:	learn: 0.0235727	total: 1.59s	remaining: 1s
# 613:	learn: 0.0235068	total: 1.59s	remaining: 1s
# 614:	learn: 0.0234556	total: 1.59s	remaining: 997ms
# 615:	learn: 0.0233994	total: 1.59s	remaining: 994ms
# 616:	learn: 0.0233565	total: 1.6s	remaining: 991ms
# 617:	learn: 0.0233151	total: 1.6s	remaining: 988ms
# 618:	learn: 0.0232761	total: 1.6s	remaining: 985ms
# 619:	learn: 0.0232470	total: 1.6s	remaining: 982ms
# 620:	learn: 0.0232183	total: 1.6s	remaining: 979ms
# 621:	learn: 0.0231675	total: 1.61s	remaining: 976ms
# 622:	learn: 0.0231399	total: 1.61s	remaining: 973ms
# 623:	learn: 0.0231150	total: 1.61s	remaining: 970ms
# 624:	learn: 0.0230911	total: 1.61s	remaining: 967ms
# 625:	learn: 0.0230515	total: 1.61s	remaining: 964ms
# 626:	learn: 0.0230008	total: 1.61s	remaining: 961ms
# 627:	learn: 0.0229600	total: 1.62s	remaining: 958ms
# 628:	learn: 0.0229130	total: 1.62s	remaining: 955ms
# 629:	learn: 0.0228720	total: 1.62s	remaining: 953ms
# 630:	learn: 0.0228480	total: 1.62s	remaining: 950ms
# 631:	learn: 0.0228111	total: 1.63s	remaining: 947ms
# 632:	learn: 0.0227748	total: 1.63s	remaining: 944ms
# 633:	learn: 0.0227181	total: 1.63s	remaining: 941ms
# 634:	learn: 0.0226923	total: 1.63s	remaining: 938ms
# 635:	learn: 0.0226245	total: 1.63s	remaining: 935ms
# 636:	learn: 0.0225787	total: 1.64s	remaining: 932ms
# 637:	learn: 0.0225573	total: 1.64s	remaining: 929ms
# 638:	learn: 0.0225147	total: 1.64s	remaining: 926ms
# 639:	learn: 0.0224917	total: 1.64s	remaining: 923ms
# 640:	learn: 0.0224504	total: 1.64s	remaining: 920ms
# 641:	learn: 0.0224030	total: 1.64s	remaining: 917ms
# 642:	learn: 0.0223651	total: 1.65s	remaining: 914ms
# 643:	learn: 0.0223214	total: 1.65s	remaining: 911ms
# 644:	learn: 0.0222887	total: 1.65s	remaining: 908ms
# 645:	learn: 0.0222449	total: 1.65s	remaining: 905ms
# 646:	learn: 0.0221969	total: 1.65s	remaining: 902ms
# 647:	learn: 0.0221393	total: 1.66s	remaining: 899ms
# 648:	learn: 0.0221118	total: 1.66s	remaining: 896ms
# 649:	learn: 0.0220638	total: 1.66s	remaining: 893ms
# 650:	learn: 0.0220181	total: 1.66s	remaining: 890ms
# 651:	learn: 0.0219711	total: 1.66s	remaining: 887ms
# 652:	learn: 0.0219033	total: 1.66s	remaining: 884ms
# 653:	learn: 0.0218499	total: 1.67s	remaining: 882ms
# 654:	learn: 0.0218175	total: 1.67s	remaining: 879ms
# 655:	learn: 0.0217880	total: 1.67s	remaining: 876ms
# 656:	learn: 0.0217434	total: 1.67s	remaining: 873ms
# 657:	learn: 0.0217047	total: 1.67s	remaining: 870ms
# 658:	learn: 0.0216615	total: 1.67s	remaining: 867ms
# 659:	learn: 0.0216326	total: 1.68s	remaining: 864ms
# 660:	learn: 0.0216013	total: 1.68s	remaining: 861ms
# 661:	learn: 0.0215722	total: 1.68s	remaining: 858ms
# 662:	learn: 0.0215330	total: 1.68s	remaining: 855ms
# 663:	learn: 0.0214744	total: 1.68s	remaining: 852ms
# 664:	learn: 0.0214400	total: 1.69s	remaining: 849ms
# 665:	learn: 0.0214143	total: 1.69s	remaining: 846ms
# 666:	learn: 0.0213901	total: 1.69s	remaining: 844ms
# 667:	learn: 0.0213604	total: 1.69s	remaining: 841ms
# 668:	learn: 0.0213248	total: 1.69s	remaining: 838ms
# 669:	learn: 0.0212842	total: 1.7s	remaining: 835ms
# 670:	learn: 0.0212482	total: 1.7s	remaining: 832ms
# 671:	learn: 0.0212178	total: 1.7s	remaining: 829ms
# 672:	learn: 0.0211611	total: 1.7s	remaining: 827ms
# 673:	learn: 0.0211212	total: 1.7s	remaining: 824ms
# 674:	learn: 0.0210914	total: 1.71s	remaining: 821ms
# 675:	learn: 0.0210495	total: 1.71s	remaining: 818ms
# 676:	learn: 0.0210046	total: 1.71s	remaining: 816ms
# 677:	learn: 0.0209758	total: 1.71s	remaining: 813ms
# 678:	learn: 0.0209354	total: 1.72s	remaining: 811ms
# 679:	learn: 0.0208898	total: 1.72s	remaining: 808ms
# 680:	learn: 0.0208370	total: 1.72s	remaining: 806ms
# 681:	learn: 0.0208112	total: 1.72s	remaining: 803ms
# 682:	learn: 0.0207694	total: 1.72s	remaining: 800ms
# 683:	learn: 0.0207281	total: 1.73s	remaining: 798ms
# 684:	learn: 0.0206911	total: 1.73s	remaining: 795ms
# 685:	learn: 0.0206476	total: 1.73s	remaining: 793ms
# 686:	learn: 0.0205986	total: 1.73s	remaining: 790ms
# 687:	learn: 0.0205690	total: 1.74s	remaining: 788ms
# 688:	learn: 0.0205332	total: 1.74s	remaining: 785ms
# 689:	learn: 0.0204960	total: 1.74s	remaining: 783ms
# 690:	learn: 0.0204734	total: 1.74s	remaining: 780ms
# 691:	learn: 0.0204243	total: 1.75s	remaining: 778ms
# 692:	learn: 0.0203815	total: 1.75s	remaining: 775ms
# 693:	learn: 0.0203443	total: 1.75s	remaining: 772ms
# 694:	learn: 0.0202617	total: 1.75s	remaining: 769ms
# 695:	learn: 0.0202265	total: 1.75s	remaining: 766ms
# 696:	learn: 0.0201970	total: 1.76s	remaining: 765ms
# 697:	learn: 0.0201743	total: 1.76s	remaining: 763ms
# 698:	learn: 0.0201509	total: 1.76s	remaining: 760ms
# 699:	learn: 0.0201096	total: 1.77s	remaining: 757ms
# 700:	learn: 0.0200717	total: 1.77s	remaining: 755ms
# 701:	learn: 0.0200447	total: 1.77s	remaining: 752ms
# 702:	learn: 0.0199948	total: 1.77s	remaining: 750ms
# 703:	learn: 0.0199562	total: 1.78s	remaining: 747ms
# 704:	learn: 0.0199342	total: 1.78s	remaining: 745ms
# 705:	learn: 0.0199073	total: 1.78s	remaining: 742ms
# 706:	learn: 0.0198742	total: 1.78s	remaining: 739ms
# 707:	learn: 0.0198457	total: 1.79s	remaining: 737ms
# 708:	learn: 0.0198215	total: 1.79s	remaining: 735ms
# 709:	learn: 0.0197906	total: 1.79s	remaining: 732ms
# 710:	learn: 0.0197572	total: 1.79s	remaining: 730ms
# 711:	learn: 0.0197302	total: 1.8s	remaining: 727ms
# 712:	learn: 0.0197086	total: 1.8s	remaining: 724ms
# 713:	learn: 0.0196701	total: 1.8s	remaining: 722ms
# 714:	learn: 0.0196494	total: 1.8s	remaining: 719ms
# 715:	learn: 0.0196328	total: 1.81s	remaining: 717ms
# 716:	learn: 0.0196056	total: 1.81s	remaining: 714ms
# 717:	learn: 0.0195807	total: 1.81s	remaining: 712ms
# 718:	learn: 0.0195461	total: 1.81s	remaining: 709ms
# 719:	learn: 0.0195074	total: 1.82s	remaining: 706ms
# 720:	learn: 0.0194642	total: 1.82s	remaining: 704ms
# 721:	learn: 0.0194306	total: 1.82s	remaining: 701ms
# 722:	learn: 0.0193921	total: 1.82s	remaining: 699ms
# 723:	learn: 0.0193566	total: 1.82s	remaining: 696ms
# 724:	learn: 0.0193004	total: 1.83s	remaining: 694ms
# 725:	learn: 0.0192668	total: 1.83s	remaining: 691ms
# 726:	learn: 0.0192480	total: 1.83s	remaining: 689ms
# 727:	learn: 0.0192078	total: 1.84s	remaining: 686ms
# 728:	learn: 0.0191847	total: 1.84s	remaining: 683ms
# 729:	learn: 0.0191626	total: 1.84s	remaining: 681ms
# 730:	learn: 0.0191315	total: 1.84s	remaining: 678ms
# 731:	learn: 0.0190800	total: 1.84s	remaining: 676ms
# 732:	learn: 0.0190595	total: 1.85s	remaining: 673ms
# 733:	learn: 0.0190310	total: 1.85s	remaining: 670ms
# 734:	learn: 0.0189936	total: 1.85s	remaining: 668ms
# 735:	learn: 0.0189787	total: 1.85s	remaining: 665ms
# 736:	learn: 0.0189628	total: 1.85s	remaining: 662ms
# 737:	learn: 0.0189375	total: 1.86s	remaining: 660ms
# 738:	learn: 0.0188996	total: 1.86s	remaining: 657ms
# 739:	learn: 0.0188679	total: 1.86s	remaining: 654ms
# 740:	learn: 0.0188319	total: 1.86s	remaining: 652ms
# 741:	learn: 0.0187999	total: 1.87s	remaining: 649ms
# 742:	learn: 0.0187695	total: 1.87s	remaining: 646ms
# 743:	learn: 0.0187347	total: 1.87s	remaining: 644ms
# 744:	learn: 0.0187143	total: 1.87s	remaining: 641ms
# 745:	learn: 0.0186694	total: 1.87s	remaining: 638ms
# 746:	learn: 0.0186356	total: 1.88s	remaining: 636ms
# 747:	learn: 0.0186134	total: 1.88s	remaining: 633ms
# 748:	learn: 0.0185915	total: 1.88s	remaining: 630ms
# 749:	learn: 0.0185619	total: 1.88s	remaining: 628ms
# 750:	learn: 0.0185291	total: 1.89s	remaining: 625ms
# 751:	learn: 0.0184906	total: 1.89s	remaining: 622ms
# 752:	learn: 0.0184701	total: 1.89s	remaining: 620ms
# 753:	learn: 0.0184465	total: 1.89s	remaining: 617ms
# 754:	learn: 0.0184112	total: 1.89s	remaining: 614ms
# 755:	learn: 0.0183891	total: 1.9s	remaining: 612ms
# 756:	learn: 0.0183548	total: 1.9s	remaining: 609ms
# 757:	learn: 0.0183216	total: 1.9s	remaining: 606ms
# 758:	learn: 0.0182826	total: 1.9s	remaining: 604ms
# 759:	learn: 0.0182529	total: 1.9s	remaining: 601ms
# 760:	learn: 0.0182293	total: 1.91s	remaining: 599ms
# 761:	learn: 0.0181838	total: 1.91s	remaining: 596ms
# 762:	learn: 0.0181677	total: 1.91s	remaining: 593ms
# 763:	learn: 0.0181496	total: 1.91s	remaining: 591ms
# 764:	learn: 0.0181318	total: 1.91s	remaining: 588ms
# 765:	learn: 0.0181144	total: 1.92s	remaining: 585ms
# 766:	learn: 0.0180948	total: 1.92s	remaining: 583ms
# 767:	learn: 0.0180674	total: 1.92s	remaining: 580ms
# 768:	learn: 0.0180246	total: 1.92s	remaining: 577ms
# 769:	learn: 0.0179866	total: 1.92s	remaining: 575ms
# 770:	learn: 0.0179495	total: 1.93s	remaining: 572ms
# 771:	learn: 0.0179326	total: 1.93s	remaining: 570ms
# 772:	learn: 0.0179141	total: 1.93s	remaining: 567ms
# 773:	learn: 0.0178877	total: 1.93s	remaining: 565ms
# 774:	learn: 0.0178658	total: 1.94s	remaining: 562ms
# 775:	learn: 0.0178226	total: 1.94s	remaining: 559ms
# 776:	learn: 0.0177858	total: 1.94s	remaining: 557ms
# 777:	learn: 0.0177716	total: 1.94s	remaining: 554ms
# 778:	learn: 0.0177444	total: 1.94s	remaining: 552ms
# 779:	learn: 0.0177120	total: 1.95s	remaining: 549ms
# 780:	learn: 0.0176841	total: 1.95s	remaining: 547ms
# 781:	learn: 0.0176528	total: 1.95s	remaining: 544ms
# 782:	learn: 0.0176375	total: 1.95s	remaining: 542ms
# 783:	learn: 0.0176138	total: 1.96s	remaining: 539ms
# 784:	learn: 0.0175905	total: 1.96s	remaining: 537ms
# 785:	learn: 0.0175620	total: 1.96s	remaining: 534ms
# 786:	learn: 0.0175313	total: 1.96s	remaining: 531ms
# 787:	learn: 0.0175140	total: 1.97s	remaining: 529ms
# 788:	learn: 0.0174873	total: 1.97s	remaining: 526ms
# 789:	learn: 0.0174581	total: 1.97s	remaining: 523ms
# 790:	learn: 0.0174269	total: 1.97s	remaining: 521ms
# 791:	learn: 0.0173831	total: 1.97s	remaining: 518ms
# 792:	learn: 0.0173503	total: 1.98s	remaining: 516ms
# 793:	learn: 0.0173304	total: 1.98s	remaining: 513ms
# 794:	learn: 0.0173053	total: 1.98s	remaining: 511ms
# 795:	learn: 0.0172800	total: 1.98s	remaining: 508ms
# 796:	learn: 0.0172442	total: 1.98s	remaining: 506ms
# 797:	learn: 0.0172199	total: 1.99s	remaining: 503ms
# 798:	learn: 0.0171938	total: 1.99s	remaining: 501ms
# 799:	learn: 0.0171673	total: 1.99s	remaining: 498ms
# 800:	learn: 0.0171355	total: 2s	remaining: 496ms
# 801:	learn: 0.0171229	total: 2s	remaining: 493ms
# 802:	learn: 0.0170948	total: 2s	remaining: 490ms
# 803:	learn: 0.0170725	total: 2s	remaining: 488ms
# 804:	learn: 0.0170562	total: 2s	remaining: 485ms
# 805:	learn: 0.0170281	total: 2.01s	remaining: 483ms
# 806:	learn: 0.0169906	total: 2.01s	remaining: 480ms
# 807:	learn: 0.0169629	total: 2.01s	remaining: 478ms
# 808:	learn: 0.0169354	total: 2.01s	remaining: 475ms
# 809:	learn: 0.0169152	total: 2.01s	remaining: 472ms
# 810:	learn: 0.0168988	total: 2.02s	remaining: 470ms
# 811:	learn: 0.0168539	total: 2.02s	remaining: 468ms
# 812:	learn: 0.0168305	total: 2.02s	remaining: 465ms
# 813:	learn: 0.0168105	total: 2.02s	remaining: 463ms
# 814:	learn: 0.0167827	total: 2.03s	remaining: 460ms
# 815:	learn: 0.0167604	total: 2.03s	remaining: 458ms
# 816:	learn: 0.0167383	total: 2.03s	remaining: 455ms
# 817:	learn: 0.0166837	total: 2.03s	remaining: 452ms
# 818:	learn: 0.0166537	total: 2.04s	remaining: 450ms
# 819:	learn: 0.0166307	total: 2.04s	remaining: 448ms
# 820:	learn: 0.0165968	total: 2.04s	remaining: 445ms
# 821:	learn: 0.0165776	total: 2.04s	remaining: 443ms
# 822:	learn: 0.0165633	total: 2.05s	remaining: 440ms
# 823:	learn: 0.0165308	total: 2.05s	remaining: 438ms
# 824:	learn: 0.0164975	total: 2.05s	remaining: 436ms
# 825:	learn: 0.0164777	total: 2.06s	remaining: 434ms
# 826:	learn: 0.0164616	total: 2.06s	remaining: 431ms
# 827:	learn: 0.0164460	total: 2.06s	remaining: 429ms
# 828:	learn: 0.0164232	total: 2.06s	remaining: 426ms
# 829:	learn: 0.0163962	total: 2.07s	remaining: 424ms
# 830:	learn: 0.0163758	total: 2.07s	remaining: 422ms
# 831:	learn: 0.0163580	total: 2.08s	remaining: 419ms
# 832:	learn: 0.0163219	total: 2.08s	remaining: 416ms
# 833:	learn: 0.0162913	total: 2.08s	remaining: 414ms
# 834:	learn: 0.0162564	total: 2.08s	remaining: 412ms
# 835:	learn: 0.0162321	total: 2.09s	remaining: 409ms
# 836:	learn: 0.0162154	total: 2.09s	remaining: 407ms
# 837:	learn: 0.0161885	total: 2.09s	remaining: 404ms
# 838:	learn: 0.0161494	total: 2.09s	remaining: 402ms
# 839:	learn: 0.0161137	total: 2.1s	remaining: 399ms
# 840:	learn: 0.0160900	total: 2.1s	remaining: 397ms
# 841:	learn: 0.0160696	total: 2.1s	remaining: 395ms
# 842:	learn: 0.0160305	total: 2.11s	remaining: 393ms
# 843:	learn: 0.0160061	total: 2.11s	remaining: 390ms
# 844:	learn: 0.0159866	total: 2.11s	remaining: 388ms
# 845:	learn: 0.0159582	total: 2.12s	remaining: 385ms
# 846:	learn: 0.0159237	total: 2.12s	remaining: 383ms
# 847:	learn: 0.0158841	total: 2.12s	remaining: 381ms
# 848:	learn: 0.0158596	total: 2.13s	remaining: 378ms
# 849:	learn: 0.0158385	total: 2.13s	remaining: 376ms
# 850:	learn: 0.0158200	total: 2.13s	remaining: 374ms
# 851:	learn: 0.0157930	total: 2.14s	remaining: 371ms
# 852:	learn: 0.0157684	total: 2.14s	remaining: 369ms
# 853:	learn: 0.0157316	total: 2.14s	remaining: 366ms
# 854:	learn: 0.0157093	total: 2.15s	remaining: 364ms
# 855:	learn: 0.0156960	total: 2.15s	remaining: 362ms
# 856:	learn: 0.0156739	total: 2.15s	remaining: 360ms
# 857:	learn: 0.0156518	total: 2.16s	remaining: 357ms
# 858:	learn: 0.0156310	total: 2.16s	remaining: 355ms
# 859:	learn: 0.0156161	total: 2.16s	remaining: 352ms
# 860:	learn: 0.0155878	total: 2.17s	remaining: 350ms
# 861:	learn: 0.0155721	total: 2.17s	remaining: 347ms
# 862:	learn: 0.0155523	total: 2.17s	remaining: 345ms
# 863:	learn: 0.0155419	total: 2.17s	remaining: 342ms
# 864:	learn: 0.0155202	total: 2.17s	remaining: 340ms
# 865:	learn: 0.0155065	total: 2.18s	remaining: 337ms
# 866:	learn: 0.0154831	total: 2.18s	remaining: 335ms
# 867:	learn: 0.0154560	total: 2.18s	remaining: 332ms
# 868:	learn: 0.0154377	total: 2.19s	remaining: 329ms
# 869:	learn: 0.0154080	total: 2.19s	remaining: 327ms
# 870:	learn: 0.0153832	total: 2.19s	remaining: 324ms
# 871:	learn: 0.0153570	total: 2.19s	remaining: 322ms
# 872:	learn: 0.0153294	total: 2.2s	remaining: 320ms
# 873:	learn: 0.0153031	total: 2.2s	remaining: 317ms
# 874:	learn: 0.0152803	total: 2.2s	remaining: 315ms
# 875:	learn: 0.0152589	total: 2.2s	remaining: 312ms
# 876:	learn: 0.0152285	total: 2.21s	remaining: 310ms
# 877:	learn: 0.0152095	total: 2.21s	remaining: 307ms
# 878:	learn: 0.0151897	total: 2.21s	remaining: 305ms
# 879:	learn: 0.0151598	total: 2.21s	remaining: 302ms
# 880:	learn: 0.0151423	total: 2.22s	remaining: 299ms
# 881:	learn: 0.0151197	total: 2.22s	remaining: 297ms
# 882:	learn: 0.0151028	total: 2.22s	remaining: 295ms
# 883:	learn: 0.0150748	total: 2.23s	remaining: 292ms
# 884:	learn: 0.0150595	total: 2.23s	remaining: 290ms
# 885:	learn: 0.0150336	total: 2.23s	remaining: 287ms
# 886:	learn: 0.0150145	total: 2.23s	remaining: 285ms
# 887:	learn: 0.0149901	total: 2.24s	remaining: 282ms
# 888:	learn: 0.0149645	total: 2.24s	remaining: 280ms
# 889:	learn: 0.0149463	total: 2.24s	remaining: 277ms
# 890:	learn: 0.0149230	total: 2.25s	remaining: 275ms
# 891:	learn: 0.0148950	total: 2.25s	remaining: 272ms
# 892:	learn: 0.0148746	total: 2.25s	remaining: 270ms
# 893:	learn: 0.0148550	total: 2.25s	remaining: 267ms
# 894:	learn: 0.0148359	total: 2.26s	remaining: 265ms
# 895:	learn: 0.0148107	total: 2.26s	remaining: 262ms
# 896:	learn: 0.0147860	total: 2.26s	remaining: 260ms
# 897:	learn: 0.0147692	total: 2.26s	remaining: 257ms
# 898:	learn: 0.0147525	total: 2.27s	remaining: 255ms
# 899:	learn: 0.0147431	total: 2.27s	remaining: 253ms
# 900:	learn: 0.0147199	total: 2.28s	remaining: 250ms
# 901:	learn: 0.0147009	total: 2.28s	remaining: 248ms
# 902:	learn: 0.0146879	total: 2.28s	remaining: 245ms
# 903:	learn: 0.0146727	total: 2.29s	remaining: 243ms
# 904:	learn: 0.0146573	total: 2.29s	remaining: 240ms
# 905:	learn: 0.0146439	total: 2.29s	remaining: 238ms
# 906:	learn: 0.0146210	total: 2.29s	remaining: 235ms
# 907:	learn: 0.0145968	total: 2.3s	remaining: 233ms
# 908:	learn: 0.0145815	total: 2.3s	remaining: 231ms
# 909:	learn: 0.0145638	total: 2.31s	remaining: 228ms
# 910:	learn: 0.0145497	total: 2.31s	remaining: 226ms
# 911:	learn: 0.0145306	total: 2.31s	remaining: 223ms
# 912:	learn: 0.0145050	total: 2.32s	remaining: 221ms
# 913:	learn: 0.0144742	total: 2.32s	remaining: 218ms
# 914:	learn: 0.0144597	total: 2.32s	remaining: 216ms
# 915:	learn: 0.0144355	total: 2.33s	remaining: 213ms
# 916:	learn: 0.0144183	total: 2.33s	remaining: 211ms
# 917:	learn: 0.0143959	total: 2.33s	remaining: 209ms
# 918:	learn: 0.0143820	total: 2.34s	remaining: 206ms
# 919:	learn: 0.0143714	total: 2.34s	remaining: 203ms
# 920:	learn: 0.0143546	total: 2.34s	remaining: 201ms
# 921:	learn: 0.0143361	total: 2.35s	remaining: 198ms
# 922:	learn: 0.0143238	total: 2.35s	remaining: 196ms
# 923:	learn: 0.0143026	total: 2.35s	remaining: 193ms
# 924:	learn: 0.0142860	total: 2.35s	remaining: 191ms
# 925:	learn: 0.0142711	total: 2.36s	remaining: 188ms
# 926:	learn: 0.0142513	total: 2.36s	remaining: 186ms
# 927:	learn: 0.0142368	total: 2.36s	remaining: 183ms
# 928:	learn: 0.0142160	total: 2.37s	remaining: 181ms
# 929:	learn: 0.0141971	total: 2.37s	remaining: 178ms
# 930:	learn: 0.0141734	total: 2.37s	remaining: 176ms
# 931:	learn: 0.0141581	total: 2.37s	remaining: 173ms
# 932:	learn: 0.0141458	total: 2.38s	remaining: 171ms
# 933:	learn: 0.0141276	total: 2.38s	remaining: 168ms
# 934:	learn: 0.0141021	total: 2.38s	remaining: 166ms
# 935:	learn: 0.0140811	total: 2.39s	remaining: 163ms
# 936:	learn: 0.0140550	total: 2.39s	remaining: 161ms
# 937:	learn: 0.0140427	total: 2.39s	remaining: 158ms
# 938:	learn: 0.0140264	total: 2.4s	remaining: 156ms
# 939:	learn: 0.0140101	total: 2.4s	remaining: 153ms
# 940:	learn: 0.0139865	total: 2.4s	remaining: 151ms
# 941:	learn: 0.0139654	total: 2.4s	remaining: 148ms
# 942:	learn: 0.0139475	total: 2.41s	remaining: 146ms
# 943:	learn: 0.0139273	total: 2.41s	remaining: 143ms
# 944:	learn: 0.0139138	total: 2.41s	remaining: 141ms
# 945:	learn: 0.0138970	total: 2.42s	remaining: 138ms
# 946:	learn: 0.0138817	total: 2.42s	remaining: 135ms
# 947:	learn: 0.0138627	total: 2.42s	remaining: 133ms
# 948:	learn: 0.0138466	total: 2.42s	remaining: 130ms
# 949:	learn: 0.0138267	total: 2.43s	remaining: 128ms
# 950:	learn: 0.0138077	total: 2.43s	remaining: 125ms
# 951:	learn: 0.0137911	total: 2.43s	remaining: 123ms
# 952:	learn: 0.0137775	total: 2.44s	remaining: 120ms
# 953:	learn: 0.0137479	total: 2.44s	remaining: 118ms
# 954:	learn: 0.0137344	total: 2.44s	remaining: 115ms
# 955:	learn: 0.0137155	total: 2.45s	remaining: 113ms
# 956:	learn: 0.0136967	total: 2.45s	remaining: 110ms
# 957:	learn: 0.0136856	total: 2.45s	remaining: 107ms
# 958:	learn: 0.0136592	total: 2.45s	remaining: 105ms
# 959:	learn: 0.0136426	total: 2.46s	remaining: 102ms
# 960:	learn: 0.0136118	total: 2.46s	remaining: 99.9ms
# 961:	learn: 0.0135973	total: 2.46s	remaining: 97.3ms
# 962:	learn: 0.0135818	total: 2.47s	remaining: 94.8ms
# 963:	learn: 0.0135624	total: 2.47s	remaining: 92.2ms
# 964:	learn: 0.0135457	total: 2.47s	remaining: 89.7ms
# 965:	learn: 0.0135267	total: 2.48s	remaining: 87.1ms
# 966:	learn: 0.0135168	total: 2.48s	remaining: 84.5ms
# 967:	learn: 0.0134993	total: 2.48s	remaining: 81.9ms
# 968:	learn: 0.0134798	total: 2.48s	remaining: 79.4ms
# 969:	learn: 0.0134693	total: 2.48s	remaining: 76.8ms
# 970:	learn: 0.0134572	total: 2.48s	remaining: 74.2ms
# 971:	learn: 0.0134469	total: 2.49s	remaining: 71.7ms
# 972:	learn: 0.0134300	total: 2.49s	remaining: 69.1ms
# 973:	learn: 0.0134156	total: 2.49s	remaining: 66.6ms
# 974:	learn: 0.0133950	total: 2.5s	remaining: 64ms
# 975:	learn: 0.0133819	total: 2.5s	remaining: 61.4ms
# 976:	learn: 0.0133692	total: 2.5s	remaining: 58.9ms
# 977:	learn: 0.0133568	total: 2.51s	remaining: 56.4ms
# 978:	learn: 0.0133487	total: 2.51s	remaining: 53.8ms
# 979:	learn: 0.0133350	total: 2.51s	remaining: 51.3ms
# 980:	learn: 0.0133198	total: 2.52s	remaining: 48.8ms
# 981:	learn: 0.0133052	total: 2.52s	remaining: 46.3ms
# 982:	learn: 0.0132881	total: 2.53s	remaining: 43.7ms
# 983:	learn: 0.0132657	total: 2.53s	remaining: 41.1ms
# 984:	learn: 0.0132470	total: 2.53s	remaining: 38.6ms
# 985:	learn: 0.0132249	total: 2.54s	remaining: 36ms
# 986:	learn: 0.0132074	total: 2.54s	remaining: 33.4ms
# 987:	learn: 0.0131901	total: 2.54s	remaining: 30.9ms
# 988:	learn: 0.0131682	total: 2.54s	remaining: 28.3ms
# 989:	learn: 0.0131575	total: 2.54s	remaining: 25.7ms
# 990:	learn: 0.0131458	total: 2.55s	remaining: 23.1ms
# 991:	learn: 0.0131257	total: 2.55s	remaining: 20.6ms
# 992:	learn: 0.0131046	total: 2.55s	remaining: 18ms
# 993:	learn: 0.0130911	total: 2.56s	remaining: 15.4ms
# 994:	learn: 0.0130801	total: 2.56s	remaining: 12.9ms
# 995:	learn: 0.0130598	total: 2.56s	remaining: 10.3ms
# 996:	learn: 0.0130442	total: 2.56s	remaining: 7.72ms
# 997:	learn: 0.0130261	total: 2.57s	remaining: 5.14ms
# 998:	learn: 0.0130129	total: 2.57s	remaining: 2.57ms
# 999:	learn: 0.0129939	total: 2.57s	remaining: 0us
# Accuracy of meta model (CatBoost): 0.9459459459459459

# %% [markdown]
# #### Hyper-parameter tuning

# %%
param_dist_svc = {
    'C': np.logspace(-3, 3, 7),
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': np.logspace(-3, 3, 7),
    'class_weight': ['balanced']
}
cv = 2
n_iter = 5
svm = SVC()

random_search_svc = random_grid_search(svm, param_dist_svc, cv, n_iter, x_train_meta, y_train_meta)
best_model_svc = random_search_svc.best_estimator_
best_accuracy_svc = random_search_svc.best_score_
best_param_svc = random_search_svc.best_params_

print(best_param_svc)
print(best_accuracy_svc)
# Out:
# Fitting 2 folds for each of 5 candidates, totalling 10 fits
# {'kernel': 'poly', 'gamma': 1000.0, 'class_weight': 'balanced', 'C': 100.0}
# 0.8945578231292517

# %%
y_pred_meta_svc_2 = best_model_svc.predict(x_valid_meta)
accuracy = accuracy_score(y_valid_meta, y_pred_meta_svc_2)
print(f"Accuracy meta model after: {accuracy}")
# Out:
# Accuracy meta model after: 0.9121621621621622

# %%
param_dist_random = {
    'n_estimators': np.arange(50, 1001, 50),
    'max_depth': np.arange(3, 20)
}
cv = 2
n_iter = 5
random = RandomForestClassifier()

random_search_random = random_grid_search(random, param_dist_random, cv, n_iter, x_train_meta, y_train_meta)
best_model_random = random_search_random.best_estimator_
best_accuracy_random = random_search_random.best_score_
best_param_random = random_search_random.best_params_

print(best_param_random)
print(best_accuracy_random)
# Out:
# Fitting 2 folds for each of 5 candidates, totalling 10 fits
# {'n_estimators': 900, 'max_depth': 8}
# 0.9506802721088435

# %%
y_pred_meta_random_2 = best_model_random.predict(x_valid_meta)
accuracy = accuracy_score(y_valid_meta, y_pred_meta_random_2)
print(f"Accuracy meta model after: {accuracy}")
# Out:
# Accuracy meta model after: 0.9459459459459459
